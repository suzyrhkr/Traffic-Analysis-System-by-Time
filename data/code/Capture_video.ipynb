# %%
import cv2
print(cv2.__version__)
# Out:
# 4.5.1

# %%
vidcap = cv2.VideoCapture('/Users/fjdks/Desktop/chaewon_docs/study/Capstone Design/we/videos/video_3/3_2.mp4')
success,image = vidcap.read()

count = 4701
success = True

while success:
    success,image = vidcap.read()
    if(int(vidcap.get(1)) % 10 == 0):
        image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)
        #image = rotateImage(image,90)

        cv2.imwrite("/Users/fjdks/Desktop/chaewon_docs/study/Capstone Design/we/saveImage/4_newbusStop/%d.jpg" % count, image)
        print("saved image %d.jpg" % count)

        if cv2.waitKey(33) == 27:                    
            break
        count += 1
    
print("Done!")
# Out:
# saved image 4701.jpg
# saved image 4702.jpg
# saved image 4703.jpg
# saved image 4704.jpg
# saved image 4705.jpg
# saved image 4706.jpg
# saved image 4707.jpg
# saved image 4708.jpg
# saved image 4709.jpg
# saved image 4710.jpg
# saved image 4711.jpg
# saved image 4712.jpg
# saved image 4713.jpg
# saved image 4714.jpg
# saved image 4715.jpg
# saved image 4716.jpg
# saved image 4717.jpg
# saved image 4718.jpg
# saved image 4719.jpg
# saved image 4720.jpg
# saved image 4721.jpg
# saved image 4722.jpg
# saved image 4723.jpg
# saved image 4724.jpg
# saved image 4725.jpg
# saved image 4726.jpg
# saved image 4727.jpg
# saved image 4728.jpg
# saved image 4729.jpg
# saved image 4730.jpg
# saved image 4731.jpg
# saved image 4732.jpg
# saved image 4733.jpg
# saved image 4734.jpg
# saved image 4735.jpg
# saved image 4736.jpg
# saved image 4737.jpg
# saved image 4738.jpg
# saved image 4739.jpg
# saved image 4740.jpg
# saved image 4741.jpg
# saved image 4742.jpg
# saved image 4743.jpg
# ...
